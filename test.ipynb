# %%
os.chdir('/Users/paulschulz/Cube_detection/training_without_rotation/own_training')

# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Klone nach 'yolov5'...
# remote: Enumerating objects: 14906, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 14906 (delta 11), reused 13 (delta 2), pack-reused 14880
# Empfange Objekte: 100% (14906/14906), 13.87 MiB | 6.74 MiB/s, fertig.
# Löse Unterschiede auf: 100% (10256/10256), fertig.

# %%
! pip install -r /Users/paulschulz/Cube_detection/training_without_rotation/own_training/yolov5/requirements.txt  # install

# %% [markdown]
# # n

# %%
os.chdir("/Users/paulschulz/Cube_detection/training_without_rotation/own_training/yolov5")

# %%
! python3 detect.py  --weights /Users/paulschulz/Cube_detection/training_without_rotation/own_training/runs/train/exp/weights/best.pt --source "/Users/paulschulz/Downloads/IMG_3445.jpeg"
# Out:
# detect: weights=['/Users/paulschulz/Cube_detection/training_without_rotation/own_training/runs/train/exp/weights/best.pt'], source=/Users/paulschulz/Downloads/IMG_3445.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-53-g65071da Python-3.9.15 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1794343 parameters, 0 gradients, 4.2 GFLOPs
# image 1/1 /Users/paulschulz/Downloads/IMG_3445.jpeg: 640x480 (no detections), 174.5ms
# Speed: 3.7ms pre-process, 174.5ms inference, 9.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp12

# %% [markdown]
# # Model is detecting something but it is trash

# %%
! python3 detect.py  --weights /Users/paulschulz/Cube_detection/training_without_rotation/own_training/runs/train/exp/weights/best.pt --source 0
# Out:
# detect: weights=['/Users/paulschulz/Cube_detection/training_without_rotation/own_training/runs/train/exp/weights/best.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-53-g65071da Python-3.9.15 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1794343 parameters, 0 gradients, 4.2 GFLOPs
# 1/1: 0...  Success (inf frames 1280x720 at 12.00 FPS)
#
# 0: 384x640 (no detections), 125.5ms
# 0: 384x640 (no detections), 119.0ms
# 0: 384x640 (no detections), 116.8ms
# 0: 384x640 (no detections), 95.5ms
# 0: 384x640 (no detections), 148.5ms
# 0: 384x640 (no detections), 98.5ms
# ...

# %%
os.chdir()

# %% [markdown]
# #
